# %% [markdown]
# KNMI done

# %%
lucht_root = './lucht_root/'


station_names = [{'number': 'NL01491', 'location': 'Overschie-A13'},
 {'number': 'NL01497', 'location': 'Rotterdam-Maasvlakte'},
 {'number': 'NL01496', 'location': 'Rotterdam-HvHolland'},
 {'number': 'NL01912', 'location': 'Ridderkerk-Voorweg'},
 {'number': 'NL49557', 'location': 'Wijk aan Zee-Bosweg'},
 {'number': 'NL10248', 'location': 'Nistelrode-Gagelstraat'},
 {'number': 'NL50013', 'location': 'Meerssen- Beekerweg'},
 {'number': 'NL50012', 'location': 'Eijsden-Trichterweg'},
 {'number': 'NL01485', 'location': 'Rotterdam-Hoogvliet'},
 {'number': 'NL01489', 'location': 'Ridderkerk-A16'},
 {'number': 'NL49701', 'location': 'Zaandam-Wagenschotpad'},
 {'number': 'NL10320', 'location': 'Burgh-Haamstede'},
 {'number': 'NL53016', 'location': 'Zevenbergen-Galgenweg'},
 {'number': 'NL10404', 'location': 'Den Haag-Rebecquestraat'},
 {'number': 'NL10445', 'location': 'Den Haag-Amsterdamse Veerkade'},
 {'number': 'NL10246', 'location': 'Fijnaart-Zwingelspaansedijk'},
 {'number': 'NL49002', 'location': 'Amsterdam-Haarlemmerweg'},
 {'number': 'NL49007', 'location': 'Amsterdam-Einsteinweg'},
 {'number': 'NL49014', 'location': 'Amsterdam-Vondelpark'},
 {'number': 'NL49016', 'location': 'Amsterdam-Westerpark'},
 {'number': 'NL49017', 'location': 'Amsterdam-Stadhouderskade'},
 {'number': 'NL49019', 'location': 'Amsterdam-Oude Schans'},
 {'number': 'NL49020', 'location': 'Amsterdam-Jan van Galenstraat'},
 {'number': 'NL49021', 'location': 'Amsterdam -Kantershof'},
 {'number': 'NL53001', 'location': 'Ossendrecht-Burgemeester Voetenstraat'},
 {'number': 'NL49003', 'location': 'Amsterdam-Nieuwendammerdijk'},
 {'number': 'NL53020', 'location': 'Strijensas Buitendijk'},
 {'number': 'NL10301', 'location': 'Zierikzee-Lange Slikweg'},
 {'number': 'NL10938', 'location': 'Groningen-Nijensteinheerd'},
 {'number': 'NL53004', 'location': 'Moerdijk-Julianastraat'},
 {'number': 'NL50002', 'location': 'Geleen-Vouershof '},
 {'number': 'NL50010', 'location': 'Maastricht-A2-Philipsweg'},
 {'number': 'NL01484', 'location': 'Rotterdam-Geulhaven'},
 {'number': 'NL10107', 'location': 'Posterholt-Vlodropperweg'},
 {'number': 'NL10722', 'location': 'Eibergen-Lintveldseweg'},
 {'number': 'NL50007', 'location': 'Maastricht-Hoge_Fronten'},
 {'number': 'NL10929', 'location': 'Valthermond-Noorderdiep'},
 {'number': 'NL10617', 'location': 'Biddinghuizen-Kuilweg'},
 {'number': 'NL10538', 'location': 'Wieringerwerf-Medemblikkerweg'},
 {'number': 'NL10741', 'location': 'Nijmegen-Graafseweg'},
 {'number': 'NL10738', 'location': 'Wekerom-Riemterdijk'},
 {'number': 'NL10138', 'location': 'Heerlen-Jamboreepad'},
 {'number': 'NL10133', 'location': 'Wijnandsrade-Opfergeltstraat'},
 {'number': 'NL10131', 'location': 'Vredepeel-Vredeweg'},
 {'number': 'NL10235', 'location': 'Huijbergen-Vennekenstraat'},
 {'number': 'NL10818', 'location': 'Barsbeek-De Veenen'},
 {'number': 'NL01493', 'location': 'Rotterdam-Statenweg'},
 {'number': 'NL50004', 'location': 'Maastricht-A2-Nassaulaan'},
 {'number': 'NL01494', 'location': 'Schiedam-A.Arienstraat'},
 {'number': 'NL50011', 'location': 'Nederweert-Kuilstraat'},
 {'number': 'NL54010', 'location': 'Arnhem GelreDome'},
 {'number': 'NL54004', 'location': 'Arnhem Velperbroek'},
 {'number': 'NL10230', 'location': 'Biest Houtakker-Biestsestraat'},
 {'number': 'NL10442', 'location': 'Dordrecht-Bamendaweg'},
 {'number': 'NL10236', 'location': 'Eindhoven-Genovevalaan'},
 {'number': 'NL10237', 'location': 'Eindhoven-Noordbrabantlaan'},
 {'number': 'NL10247', 'location': 'Veldhoven-Europalaan'},
 {'number': 'NL10550', 'location': 'Haarlem-Schipholweg'},
 {'number': 'NL49561', 'location': 'Badhoevedorp-Sloterweg'},
 {'number': 'NL49565', 'location': 'Oude Meer-Aalsmeerderdijk'},
 {'number': 'NL10641', 'location': 'Breukelen-A2'},
 {'number': 'NL10807', 'location': 'Hellendoorn-Luttenbergerweg'},
 {'number': 'NL10633', 'location': 'Zegveld-Oude Meije'},
 {'number': 'NL10636', 'location': 'Utrecht-Kardinaal de Jongweg'},
 {'number': 'NL10318', 'location': 'Philippine-Stelleweg'},
 {'number': 'NL10643', 'location': 'Utrecht-Griftpark'},
 {'number': 'NL10437', 'location': 'Westmaas-Groeneweg'},
 {'number': 'NL10241', 'location': 'Breda-Bastenakenstraat'},
 {'number': 'NL49012', 'location': 'Amsterdam-Van Diemenstraat'},
 {'number': 'NL49553', 'location': 'Wijk aan Zee-De Banjaert'},
 {'number': 'NL49572', 'location': 'Velsen-Staalstraat'},
 {'number': 'NL49703', 'location': 'Spaarnwoude-Machineweg'},
 {'number': 'NL49556', 'location': 'De Rijp-Oostdijkje'},
 {'number': 'NL49546', 'location': 'Zaanstad-Hemkade'},
 {'number': 'NL49022', 'location': 'Amsterdam-Ookmeer'},
 {'number': 'NL10446', 'location': 'Den Haag-Bleriotlaan'},
 {'number': 'NL10644', 'location': 'Cabauw-Wielsekade'},
 {'number': 'NL10918', 'location': 'Balk-Trophornsterweg'},
 {'number': 'NL49704', 'location': 'Zaanstad-Hoogtij'},
 {'number': 'NL10418', 'location': 'Rotterdam-Schiedamsevest'},
 {'number': 'NL10937', 'location': 'Groningen-Europaweg'},
 {'number': 'NL10136', 'location': 'Heerlen-Looierstraat'},
 {'number': 'NL10240', 'location': 'Breda-Tilburgseweg'},
 {'number': 'NL10742', 'location': 'Nijmegen-Ruyterstraat'},
 {'number': 'NL10821', 'location': 'Enschede-Winkelshorst'},
 {'number': 'NL49551', 'location': 'IJmuiden-Kanaalstraat'},
 {'number': 'NL49570', 'location': 'Beverwijk-Creutzberglaan'},
 {'number': 'NL49564', 'location': 'Hoofddorp-Hoofdweg'},
 {'number': 'NL49573', 'location': 'Velsen-Reyndersweg'},
 {'number': 'NL10639', 'location': 'Utrecht-Constant Erzeijstraat'},
 {'number': 'NL10444', 'location': 'De Zilk-Vogelaarsdreef'},
 {'number': 'NL53015', 'location': 'Klundert-Kerkweg'},
 {'number': 'NL01487', 'location': 'Rotterdam-Pleinweg'},
 {'number': 'NL01488', 'location': 'Rotterdam-Zwartewaalstraat'},
 {'number': 'NL01495', 'location': 'Maassluis-Kwartellaan'},
 {'number': 'NL10449', 'location': 'Vlaardingen-Riouwlaan'},
 {'number': 'NL10450', 'location': 'Den Haag-Neherkade'},
 {'number': 'NL10934', 'location': 'Kollumerwaard-Hooge Zuidwal'},
 {'number': 'NL49680', 'location': 'Almere-Boomgaardweg'},
 {'number': 'NL01913', 'location': 'Sluiskil-Stroodorpestraat'},
 {'number': 'NL50003', 'location': 'Geleen-Asterstraat'}]


import requests
import time
import datetime
import pandas as pd
import os
import json
import math
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
import aiohttp
import asyncio
import time
import random
import datetime
from datetime import datetime

# %%
session = requests.Session()

retry = Retry(connect=3, backoff_factor =0.5)
adapter = HTTPAdapter(max_retries = retry)
session.mount('http://',adapter)
session.mount('https://', adapter)

page_start = 100
page_final = 200
skipped_pages = {}

MAX_REQS = 300
MAX_TIME_ELAPSED = 300

def health_check(req_nums, time_start):
    req_nums += 1
    span = time.time() - time_start

    if req_nums > 80 and req_nums/span > 3:
        print(f'pausing for {(req_nums-span)+30} seconds to avoid a timeout')
        time.sleep((req_nums-span)+30)
        return 0, time.time()

    if req_nums > 250:
        if (span) > 290:
            print(f'{req_nums} in >290 secs, no need to pause')
        else:
            print(f'pausing for {310-span} seconds to avoid a timeout')
            time.sleep(310-span)
        return 0, time.time()
    else:
        return req_nums, time_start



# def health_check(req_nums, time_start):
#     req_nums += 1
#     time_elapsed = time.time()-time_start

#     if req_nums > 145 and req_nums > time_elapsed:
#         print(f'Calls too fast. {req_nums} calls in {time_elapsed}s - pausing for {20+(req_nums - math.floor(time_elapsed))}s.')
#         time.sleep(20+(req_nums - math.floor(time_elapsed)))
#         return 0, time.time()
#     elif req_nums > 50 and req_nums/time_elapsed > 2:
#         print(f'Calls too fast. {req_nums} calls in {time_elapsed}s - pausing for {20}s.')
#         time.sleep(20)
#         return 0, time.time()
#     else:
#         return req_nums, time_start
    
def get_req(session, url):

    req = session.get(url)

    if req.status_code == 200:
        # print('successfully pulled, ', url)
        return req
    elif req.status_code == 429:
        print('Request limit, pausing for 5 minutes.')
        print('time now:', datetime.now())
        looper = True
        while(looper):
            time.sleep(300)
            req = session.get(url)
            if req.status_code != 429:
                looper == False
                print('Stopping pause, time now:', datetime.now())
                break
    elif req.status_code == 404:
        print('error code 404, skipping station', url)
    else:
        print('unkown error status code: ', req.status_code)

    return req

def dump_json(json_data, path):
    with open(path, 'w') as json_file:
        json.dump(json_data, json_file, indent=4)

def dump_csv(csv_data, path):
    csv_data.to_csv(path, index=False)

def get_page(req):
    page_data = []
    if 'data' in req.json().keys():
        for values in req.json()['data']:
            page_data.append([values['timestamp_measured'],values['value']])
        return page_data
    else:
        print(f'Skipping {req.json()} because no data.')
        return []
    

component_units = {
    'SO2': 'µg/m3',
    'PM25': 'µg/m3',
    'PM10': 'µg/m3',
    'Ox': 'ppb',
    'O3': 'µg/m3',
    'BC': 'µg/m3',
    'CO': 'µg/m3',
    'H2S': 'µg/m3',
    'NH3': 'µg/m3',
    'NO2': 'µg/m3',
    'NO': 'µg/m3',
    'NOx': 'µg/m3',
    'BTX': 'µg/m3',
    'HC Aerosol': 'µg/m3',
    'HC Regenwater': 'µmol/L',
    'Koolstof aerosol': 'µg/m3',
    'Lindane regenwater': 'µmol/L',
    'PAK Aerosol': 'ng/m3',
    'ZM Aerosol': 'ng/m3',
    'ZM Regenwater': 'µmol/L',
    'ZVOC': 'ng/m3',
    'VOC': 'µg/m3',
    'Kwik Regenwater': 'mm'
}

# %%
component_units = {k: v.replace('µ', 'u') for k, v in component_units.items()}

full_start_time = time.time()
skipped_stations =[]
req_nums = 0
time_start = time.time()
for station in station_names[1:2]:
    station_name = station['number']
    station_dir = os.path.join(lucht_root,station_name)
    json_path = os.path.join(station_dir, f'{station_name}.json')
    csv_path = os.path.join(station_dir, f'{station_name}.csv')

    os.makedirs(station_dir, exist_ok=True)

    station_url = f'https://api2020.luchtmeetnet.nl/open_api/stations/{station_name}'
    station_req = get_req(session,station_url)
    print(f'pulling station info: {station_url}')
    req_nums, time_start = health_check(req_nums, time_start)
    if station_req.status_code != 200:
        skipped_stations.append(station)
        print(f'Skipping station {station_name}')
        continue
    else:
        json_data = {
        "type": 'official_unval',
        'longitude': station_req.json()['data']['geometry']['coordinates'][0],
        'latitude': station_req.json()['data']['geometry']['coordinates'][1],
        'organisation': station_req.json()['data']['organisation'],
        'location': station_req.json()['data']['location'],
        'year_start': station_req.json()['data']['year_start'],
        'municipality': station_req.json()['data']['municipality'],
        'locality_type': station_req.json()['data']['type'],
        'datastreams_links': f'https://api2020.luchtmeetnet.nl/open_api/stations/{station["number"]}'
}
        components = station_req.json()['data']['components']
        json_data['stream_units']={}
        for component in components:
            if component in component_units:
                json_data['stream_units'][component] = component_units[component]
            elif 'C6' or 'C7' or 'C8' in component:
                json_data['stream_units'][component] = 'ug/m3'
            else:
                json_data['stream_units'][component] = 'null' 
        data_check = get_req(session,f'https://api2020.luchtmeetnet.nl/open_api/stations/{station_name}/measurements')
        print(f'Verifying availability of data in: https://api2020.luchtmeetnet.nl/open_api/stations/{station_name}/measurements')        
        req_nums, time_start = health_check(req_nums, time_start)
        try:
            if data_check.json()['data'] == []:
                json_data['has_data'] = 'False'
            else:
                json_data['has_data'] = 'True'
        except:
            print(f'{station_name} response error code, could not verified if theres data, skipping to next station')
            skipped_stations.append(station)
            continue
        total_data = pd.DataFrame() 
        for component in components:
            total_component_data = []
            page = 1
            component_url = f'https://api2020.luchtmeetnet.nl/open_api/stations/{station_name}/measurements?formula={component}&page={page}'  
            page_req = get_req(session,component_url)             
            req_nums, time_start = health_check(req_nums, time_start)
            req_check = 0
            lastpage = 900
            if page_req.status_code != 200:
                while(page_req.status_code != 200):
                    page_req = get_req(session,component_url)             
                    req_nums, time_start = health_check(req_nums, time_start)
                    req_check += 1
                    if req_check == 20:
                        break
                    time.sleep(10)
            if page_req.status_code == 200:
                if page_req.json()['pagination']['last_page'] < lastpage:
                    lastpage = page_req.json()['pagination']['last_page']
            if lastpage == 0:
                continue
            print(f'last page for this component is: {lastpage}')
            while(page <= 100):
                print('time now:', datetime.now())
                component_url = f'https://api2020.luchtmeetnet.nl/open_api/stations/{station_name}/measurements?formula={component}&page={page}'  
                page_req = get_req(session,component_url)             
                req_nums, time_start = health_check(req_nums, time_start)
                print(f'pulling from: {component_url}')
                if page_req.status_code != 200:
                    page_req = get_req(session,component_url)
                    req_nums, time_start = health_check(req_nums, time_start) 
                if page_req.status_code !=200: 
                    print(f'Skipping page {page} in station {station_name} in component {component}')
                    page+=1
                    continue
                if page == page_req.json()['pagination']['last_page']:
                    lastpage = True
                else:
                    page+=1
                total_component_data.extend(get_page(page_req))
                del page_req
            if total_data.empty:
                total_data[['time',component]] = total_component_data
                total_data['time'] = pd.to_datetime(total_data['time']).apply(lambda x: int(x.timestamp()))
                total_data = total_data.drop_duplicates(subset='time',keep='first')
                #api is in gmt?
            else:
                dum_component_data = pd.DataFrame(total_component_data, columns=['time',component])
                dum_component_data['time'] = pd.to_datetime(dum_component_data['time']).apply(lambda x: int(x.timestamp()))        
                dum_component_data = dum_component_data.drop_duplicates(subset='time',keep='first')
                total_data = pd.merge(total_data, dum_component_data, on='time',how='outer')
                del dum_component_data
            del total_component_data

        if total_data.empty:
            json_data['has_data'] = 'False'
        else:
            dump_csv(total_data,csv_path)
            json_data['has_data'] = 'True'
        
        print(f'Total time so far: {math.floor((time.time() - full_start_time)/60)} m {(time.time() - full_start_time)%60} s')
        json_data['available_streams'] = list(total_data.columns[1:])
        dump_json(json_data, json_path)

        del data_check,total_data, json_data
# Out:
# pulling station info: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497
# Verifying availability of data in: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements
# last page for this component is: 716
# time now: 2026-01-13 10:14:38.021809
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=1
# time now: 2026-01-13 10:14:38.063224
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=2
# time now: 2026-01-13 10:14:38.260611
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=3
# time now: 2026-01-13 10:14:38.488737
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=4
# time now: 2026-01-13 10:14:38.798855
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=5
# time now: 2026-01-13 10:14:39.204140
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=6
# time now: 2026-01-13 10:14:39.557843
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=7
# time now: 2026-01-13 10:14:39.900760
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=8
# time now: 2026-01-13 10:14:40.293576
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=9
# time now: 2026-01-13 10:14:40.670564
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=10
# time now: 2026-01-13 10:14:41.078688
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=11
# time now: 2026-01-13 10:14:41.561999
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=12
# time now: 2026-01-13 10:14:42.074105
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=13
# time now: 2026-01-13 10:14:42.585525
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=14
# time now: 2026-01-13 10:14:43.080459
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=15
# time now: 2026-01-13 10:14:43.711719
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=16
# time now: 2026-01-13 10:14:44.428714
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=17
# time now: 2026-01-13 10:14:45.075660
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=18
# time now: 2026-01-13 10:14:45.858046
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=19
# time now: 2026-01-13 10:14:46.542245
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=20
# time now: 2026-01-13 10:14:47.250437
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=21
# time now: 2026-01-13 10:14:48.013354
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=22
# time now: 2026-01-13 10:14:48.831736
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=23
# time now: 2026-01-13 10:14:49.651037
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=24
# time now: 2026-01-13 10:14:50.573742
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=25
# time now: 2026-01-13 10:14:51.494938
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=26
# time now: 2026-01-13 10:14:52.517130
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=27
# time now: 2026-01-13 10:14:53.440769
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=28
# time now: 2026-01-13 10:14:54.447017
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=29
# time now: 2026-01-13 10:14:55.498014
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=30
# time now: 2026-01-13 10:14:56.490982
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=31
# time now: 2026-01-13 10:14:57.489450
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=32
# time now: 2026-01-13 10:14:58.969165
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=33
# time now: 2026-01-13 10:15:00.095622
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=34
# time now: 2026-01-13 10:15:01.426915
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=35
# time now: 2026-01-13 10:15:02.860181
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=36
# time now: 2026-01-13 10:15:04.598929
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=37
# time now: 2026-01-13 10:15:06.151114
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=38
# time now: 2026-01-13 10:15:07.470413
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=39
# time now: 2026-01-13 10:15:08.902467
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=40
# time now: 2026-01-13 10:15:10.335500
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=41
# time now: 2026-01-13 10:15:11.769194
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=42
# time now: 2026-01-13 10:15:13.207762
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=43
# time now: 2026-01-13 10:15:14.737895
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=44
# time now: 2026-01-13 10:15:16.374076
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=45
# time now: 2026-01-13 10:15:17.913664
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=46
# time now: 2026-01-13 10:15:19.449532
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=47
# time now: 2026-01-13 10:15:20.985683
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=48
# time now: 2026-01-13 10:15:22.621907
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=49
# time now: 2026-01-13 10:15:24.258811
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=50
# time now: 2026-01-13 10:15:25.806865
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=51
# time now: 2026-01-13 10:15:27.436802
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=52
# time now: 2026-01-13 10:15:29.078434
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=53
# time now: 2026-01-13 10:15:30.687468
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=54
# time now: 2026-01-13 10:15:32.351522
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=55
# time now: 2026-01-13 10:15:33.992141
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=56
# time now: 2026-01-13 10:15:35.672659
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=57
# time now: 2026-01-13 10:15:37.472265
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=58
# time now: 2026-01-13 10:15:39.315382
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=59
# time now: 2026-01-13 10:15:41.056115
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=60
# time now: 2026-01-13 10:15:42.799588
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=61
# time now: 2026-01-13 10:15:44.677407
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=62
# time now: 2026-01-13 10:15:46.689851
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=63
# time now: 2026-01-13 10:15:48.633908
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=64
# time now: 2026-01-13 10:15:50.784632
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=65
# time now: 2026-01-13 10:15:52.752497
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=66
# time now: 2026-01-13 10:15:54.686803
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=67
# time now: 2026-01-13 10:15:56.723472
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=68
# time now: 2026-01-13 10:15:58.771081
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=69
# time now: 2026-01-13 10:16:00.927289
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=70
# time now: 2026-01-13 10:16:02.982231
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=71
# time now: 2026-01-13 10:16:05.120809
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=72
# time now: 2026-01-13 10:16:07.283620
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=73
# time now: 2026-01-13 10:16:09.523522
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=74
# time now: 2026-01-13 10:16:11.736197
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=75
# time now: 2026-01-13 10:16:13.941578
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=76
# time now: 2026-01-13 10:16:16.281760
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=77
# time now: 2026-01-13 10:16:18.496242
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=78
# time now: 2026-01-13 10:16:20.955839
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=79
# time now: 2026-01-13 10:16:23.244547
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=80
# time now: 2026-01-13 10:16:25.805632
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=81
# time now: 2026-01-13 10:16:28.160237
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=82
# time now: 2026-01-13 10:16:30.700344
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=83
# time now: 2026-01-13 10:16:33.179119
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=84
# time now: 2026-01-13 10:16:35.737562
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=85
# time now: 2026-01-13 10:16:38.298837
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=86
# time now: 2026-01-13 10:16:41.208963
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=87
# time now: 2026-01-13 10:16:43.833453
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=88
# time now: 2026-01-13 10:16:46.488809
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=89
# time now: 2026-01-13 10:16:49.328369
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=90
# time now: 2026-01-13 10:16:52.043530
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=91
# time now: 2026-01-13 10:16:54.992107
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=92
# time now: 2026-01-13 10:16:57.754481
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=93
# time now: 2026-01-13 10:17:00.659016
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=94
# time now: 2026-01-13 10:17:03.488786
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=95
# time now: 2026-01-13 10:17:06.560864
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=96
# time now: 2026-01-13 10:17:09.455539
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=97
# time now: 2026-01-13 10:17:12.400164
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=98
# time now: 2026-01-13 10:17:15.676205
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=99
# time now: 2026-01-13 10:17:18.607538
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO2&page=100
# last page for this component is: 716
# time now: 2026-01-13 10:17:21.817095
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=1
# time now: 2026-01-13 10:17:21.859462
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=2
# time now: 2026-01-13 10:17:22.048011
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=3
# time now: 2026-01-13 10:17:22.330544
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=4
# time now: 2026-01-13 10:17:22.640344
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=5
# time now: 2026-01-13 10:17:23.045516
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=6
# time now: 2026-01-13 10:17:23.457410
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=7
# time now: 2026-01-13 10:17:23.866372
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=8
# time now: 2026-01-13 10:17:24.275006
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=9
# time now: 2026-01-13 10:17:24.688602
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=10
# time now: 2026-01-13 10:17:25.094668
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=11
# time now: 2026-01-13 10:17:25.571309
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=12
# time now: 2026-01-13 10:17:26.044589
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=13
# time now: 2026-01-13 10:17:26.632738
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=14
# time now: 2026-01-13 10:17:27.386573
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=15
# time now: 2026-01-13 10:17:27.953391
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=16
# time now: 2026-01-13 10:17:28.650904
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=17
# time now: 2026-01-13 10:17:29.367472
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=18
# time now: 2026-01-13 10:17:30.115226
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=19
# time now: 2026-01-13 10:17:30.833068
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=20
# time now: 2026-01-13 10:17:31.648997
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=21
# time now: 2026-01-13 10:17:32.365762
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=22
# time now: 2026-01-13 10:17:33.185153
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=23
# time now: 2026-01-13 10:17:34.003710
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=24
# time now: 2026-01-13 10:17:34.823518
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=25
# time now: 2026-01-13 10:17:35.642710
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=26
# time now: 2026-01-13 10:17:36.564866
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=27
# time now: 2026-01-13 10:17:37.474972
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=28
# time now: 2026-01-13 10:17:38.423219
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=29
# time now: 2026-01-13 10:17:39.495641
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=30
# time now: 2026-01-13 10:17:40.455629
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=31
# time now: 2026-01-13 10:17:41.479471
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=32
# time now: 2026-01-13 10:17:42.502941
# Request limit, pausing for 5 minutes.
# time now: 2026-01-13 10:17:42.534452
# Stopping pause, time now: 2026-01-13 10:45:48.161263
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=33
# time now: 2026-01-13 10:45:48.161651
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=34
# time now: 2026-01-13 10:45:49.275558
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=35
# time now: 2026-01-13 10:45:50.421531
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=36
# time now: 2026-01-13 10:45:51.596359
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=37
# time now: 2026-01-13 10:45:52.786838
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=38
# time now: 2026-01-13 10:45:53.942913
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=39
# time now: 2026-01-13 10:45:55.202149
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=40
# time now: 2026-01-13 10:45:56.520338
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=41
# time now: 2026-01-13 10:45:57.776480
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=42
# time now: 2026-01-13 10:45:59.147167
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=43
# time now: 2026-01-13 10:46:00.603306
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=44
# time now: 2026-01-13 10:46:01.910317
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=45
# time now: 2026-01-13 10:46:03.280337
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=46
# time now: 2026-01-13 10:46:04.713393
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=47
# time now: 2026-01-13 10:46:06.555918
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=48
# time now: 2026-01-13 10:46:08.158655
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=49
# time now: 2026-01-13 10:46:09.732609
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=50
# time now: 2026-01-13 10:46:11.329971
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=51
# time now: 2026-01-13 10:46:12.802360
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=52
# time now: 2026-01-13 10:46:14.425979
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=53
# time now: 2026-01-13 10:46:16.019000
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=54
# time now: 2026-01-13 10:46:17.617030
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=55
# time now: 2026-01-13 10:46:19.401420
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=56
# time now: 2026-01-13 10:46:21.063079
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=57
# time now: 2026-01-13 10:46:22.803581
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=58
# time now: 2026-01-13 10:46:24.564267
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=59
# time now: 2026-01-13 10:46:26.267994
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=60
# time now: 2026-01-13 10:46:28.081548
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=61
# time now: 2026-01-13 10:46:30.099183
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=62
# time now: 2026-01-13 10:46:31.868201
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=63
# time now: 2026-01-13 10:46:33.795013
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=64
# time now: 2026-01-13 10:46:35.740385
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=65
# time now: 2026-01-13 10:46:37.842020
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=66
# time now: 2026-01-13 10:46:39.857344
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=67
# time now: 2026-01-13 10:46:41.987131
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=68
# time now: 2026-01-13 10:46:44.034620
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=69
# time now: 2026-01-13 10:46:46.177996
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=70
# time now: 2026-01-13 10:46:48.310337
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=71
# time now: 2026-01-13 10:46:50.486188
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=72
# time now: 2026-01-13 10:46:52.841144
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=73
# time now: 2026-01-13 10:46:54.992575
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=74
# time now: 2026-01-13 10:46:57.150859
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=75
# time now: 2026-01-13 10:46:59.449336
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=76
# time now: 2026-01-13 10:47:01.751285
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=77
# time now: 2026-01-13 10:47:04.016361
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=78
# time now: 2026-01-13 10:47:06.363434
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=79
# time now: 2026-01-13 10:47:08.765284
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=80
# time now: 2026-01-13 10:47:11.068503
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=81
# time now: 2026-01-13 10:47:13.391105
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=82
# time now: 2026-01-13 10:47:16.000316
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=83
# time now: 2026-01-13 10:47:18.386451
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=84
# time now: 2026-01-13 10:47:20.898379
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=85
# time now: 2026-01-13 10:47:23.355647
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=86
# time now: 2026-01-13 10:47:25.906511
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=87
# time now: 2026-01-13 10:47:28.367023
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=88
# time now: 2026-01-13 10:47:31.036877
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=89
# time now: 2026-01-13 10:47:33.699158
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=90
# time now: 2026-01-13 10:47:36.283955
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=91
# time now: 2026-01-13 10:47:38.922749
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=92
# time now: 2026-01-13 10:47:41.560821
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=93
# time now: 2026-01-13 10:47:44.449111
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=94
# time now: 2026-01-13 10:47:47.278250
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=95
# time now: 2026-01-13 10:47:50.083518
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=96
# time now: 2026-01-13 10:47:52.906947
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=97
# time now: 2026-01-13 10:47:55.851406
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=98
# time now: 2026-01-13 10:47:58.685136
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=99
# time now: 2026-01-13 10:48:01.859151
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=NO&page=100
# last page for this component is: 711
# time now: 2026-01-13 10:48:05.219622
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=PM10&page=1
# time now: 2026-01-13 10:48:05.247973
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=PM10&page=2
# time now: 2026-01-13 10:48:05.532282
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=PM10&page=3
# time now: 2026-01-13 10:48:05.792278
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=PM10&page=4
# time now: 2026-01-13 10:48:06.161756
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=PM10&page=5
# time now: 2026-01-13 10:48:06.570278
# pulling from: https://api2020.luchtmeetnet.nl/open_api/stations/NL01497/measurements?formula=PM10&page=6
# time now: 2026-01-13 10:48:06.978670
